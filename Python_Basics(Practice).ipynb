# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhinesh-Fedor/Python---Basics/blob/main/Python_Basics(Practice).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#loading dataset

import pandas as pd
from datetime import datetime as dt

data_set = pd.read_csv('flowdata.csv')
data_set
# Out:
#                       Time   L06_347  LS06_347  LS06_348
# 0      2009-01-01 00:00:00  0.137417  0.097500  0.016833
# 1      2009-01-01 03:00:00  0.131250  0.088833  0.016417
# 2      2009-01-01 06:00:00  0.113500  0.091250  0.016750
# 3      2009-01-01 09:00:00  0.135750  0.091500  0.016250
# 4      2009-01-01 12:00:00  0.140917  0.096167  0.017000
# ...                    ...       ...       ...       ...
# 11692  2013-01-01 12:00:00  1.710000  1.710000  0.129583
# 11693  2013-01-01 15:00:00  1.420000  1.420000  0.096333
# 11694  2013-01-01 18:00:00  1.178583  1.178583  0.083083
# 11695  2013-01-01 21:00:00  0.898250  0.898250  0.077167
# 11696  2013-01-02 00:00:00  0.860000  0.860000  0.075000
#
# [11697 rows x 4 columns]

# %%
data_set.head()
# Out:
#                   Time   L06_347  LS06_347  LS06_348
# 0  2009-01-01 00:00:00  0.137417  0.097500  0.016833
# 1  2009-01-01 03:00:00  0.131250  0.088833  0.016417
# 2  2009-01-01 06:00:00  0.113500  0.091250  0.016750
# 3  2009-01-01 09:00:00  0.135750  0.091500  0.016250
# 4  2009-01-01 12:00:00  0.140917  0.096167  0.017000

# %%
print(data_set.info)
# Out:
# <bound method DataFrame.info of                       Time   L06_347  LS06_347  LS06_348
# 0      2009-01-01 00:00:00  0.137417  0.097500  0.016833
# 1      2009-01-01 03:00:00  0.131250  0.088833  0.016417
# 2      2009-01-01 06:00:00  0.113500  0.091250  0.016750
# 3      2009-01-01 09:00:00  0.135750  0.091500  0.016250
# 4      2009-01-01 12:00:00  0.140917  0.096167  0.017000
# ...                    ...       ...       ...       ...
# 11692  2013-01-01 12:00:00  1.710000  1.710000  0.129583
# 11693  2013-01-01 15:00:00  1.420000  1.420000  0.096333
# 11694  2013-01-01 18:00:00  1.178583  1.178583  0.083083
# 11695  2013-01-01 21:00:00  0.898250  0.898250  0.077167
# 11696  2013-01-02 00:00:00  0.860000  0.860000  0.075000
#
# [11697 rows x 4 columns]>

# %%
data_set.plot()
# Out:
# <Axes: >

# %%
#Setting time as index
data1 = data_set.set_index('Time')
data1
# Out:
#                       L06_347  LS06_347  LS06_348
# Time
# 2009-01-01 00:00:00  0.137417  0.097500  0.016833
# 2009-01-01 03:00:00  0.131250  0.088833  0.016417
# 2009-01-01 06:00:00  0.113500  0.091250  0.016750
# 2009-01-01 09:00:00  0.135750  0.091500  0.016250
# 2009-01-01 12:00:00  0.140917  0.096167  0.017000
# ...                       ...       ...       ...
# 2013-01-01 12:00:00  1.710000  1.710000  0.129583
# 2013-01-01 15:00:00  1.420000  1.420000  0.096333
# 2013-01-01 18:00:00  1.178583  1.178583  0.083083
# 2013-01-01 21:00:00  0.898250  0.898250  0.077167
# 2013-01-02 00:00:00  0.860000  0.860000  0.075000
#
# [11697 rows x 3 columns]

# %%
#printing the indices

data1.index
# Out:
# Index(['2009-01-01 00:00:00', '2009-01-01 03:00:00', '2009-01-01 06:00:00',
#        '2009-01-01 09:00:00', '2009-01-01 12:00:00', '2009-01-01 15:00:00',
#        '2009-01-01 18:00:00', '2009-01-01 21:00:00', '2009-01-02 00:00:00',
#        '2009-01-02 03:00:00',
#        ...
#        '2012-12-31 21:00:00', '2013-01-01 00:00:00', '2013-01-01 03:00:00',
#        '2013-01-01 06:00:00', '2013-01-01 09:00:00', '2013-01-01 12:00:00',
#        '2013-01-01 15:00:00', '2013-01-01 18:00:00', '2013-01-01 21:00:00',
#        '2013-01-02 00:00:00'],
#       dtype='object', name='Time', length=11697)

# %%
#Exercise-1

#Select all data starting from 2012

data2 = data1['2012-01-01 0:00:00':]
data2
# Out:
#                       L06_347  LS06_347  LS06_348
# Time
# 2012-01-01 12:00:00  0.295000  0.285167  0.031750
# 2012-01-01 15:00:00  0.301417  0.287750  0.031417
# 2012-01-01 18:00:00  0.322083  0.304167  0.038083
# 2012-01-01 21:00:00  0.355417  0.346500  0.080917
# 2012-01-02 00:00:00  1.069333  0.970000  0.071917
# ...                       ...       ...       ...
# 2013-01-01 12:00:00  1.710000  1.710000  0.129583
# 2013-01-01 15:00:00  1.420000  1.420000  0.096333
# 2013-01-01 18:00:00  1.178583  1.178583  0.083083
# 2013-01-01 21:00:00  0.898250  0.898250  0.077167
# 2013-01-02 00:00:00  0.860000  0.860000  0.075000
#
# [2933 rows x 3 columns]

# %%
#Exercise 2

#select all data in january for all different years

data1.index = pd.to_datetime(data1.index)

data3 = data1[data1.index.month == 1]
data3
# Out:
#                       L06_347  LS06_347  LS06_348
# Time
# 2009-01-01 00:00:00  0.137417  0.097500  0.016833
# 2009-01-01 03:00:00  0.131250  0.088833  0.016417
# 2009-01-01 06:00:00  0.113500  0.091250  0.016750
# 2009-01-01 09:00:00  0.135750  0.091500  0.016250
# 2009-01-01 12:00:00  0.140917  0.096167  0.017000
# ...                       ...       ...       ...
# 2013-01-01 12:00:00  1.710000  1.710000  0.129583
# 2013-01-01 15:00:00  1.420000  1.420000  0.096333
# 2013-01-01 18:00:00  1.178583  1.178583  0.083083
# 2013-01-01 21:00:00  0.898250  0.898250  0.077167
# 2013-01-02 00:00:00  0.860000  0.860000  0.075000
#
# [1001 rows x 3 columns]

# %%
# Exercise 3
#select all data in January, February and March for all different years


data4 = data1[(data1.index.month == 1) | (data1.index.month == 2) | (data1.index.month == 3)]
data4
# Out:
#                       L06_347  LS06_347  LS06_348
# Time
# 2009-01-01 00:00:00  0.137417  0.097500  0.016833
# 2009-01-01 03:00:00  0.131250  0.088833  0.016417
# 2009-01-01 06:00:00  0.113500  0.091250  0.016750
# 2009-01-01 09:00:00  0.135750  0.091500  0.016250
# 2009-01-01 12:00:00  0.140917  0.096167  0.017000
# ...                       ...       ...       ...
# 2013-01-01 12:00:00  1.710000  1.710000  0.129583
# 2013-01-01 15:00:00  1.420000  1.420000  0.096333
# 2013-01-01 18:00:00  1.178583  1.178583  0.083083
# 2013-01-01 21:00:00  0.898250  0.898250  0.077167
# 2013-01-02 00:00:00  0.860000  0.860000  0.075000
#
# [2897 rows x 3 columns]

# %%
# Exercise 4
#select all 'daytime' data (between 8h and 20h) for all days

data5 = data1[(data1.index.hour >= 8) & (data1.index.hour <= 20)]
data5
# Out:
#                       L06_347  LS06_347  LS06_348
# Time
# 2009-01-01 09:00:00  0.135750  0.091500  0.016250
# 2009-01-01 12:00:00  0.140917  0.096167  0.017000
# 2009-01-01 15:00:00  0.099167  0.091667  0.017583
# 2009-01-01 18:00:00  0.132667  0.090167  0.016250
# 2009-01-02 09:00:00  0.141917  0.097083  0.016417
# ...                       ...       ...       ...
# 2012-12-31 18:00:00  0.617333  0.617333  0.060583
# 2013-01-01 09:00:00  2.055000  2.055000  0.175667
# 2013-01-01 12:00:00  1.710000  1.710000  0.129583
# 2013-01-01 15:00:00  1.420000  1.420000  0.096333
# 2013-01-01 18:00:00  1.178583  1.178583  0.083083
#
# [5848 rows x 3 columns]

# %%
#IPS
def check_password(password):
  if not password[0].isalpha():
    print("Bad")
    return
  if len(password) < 8:
    print("Bad")
    return
  if not any(a.isdigit() for a in password):
    print("Bad")
    return
  if not any(a in "@$!%*?&" for a in password):
    print("Bad")
    return
  print("Good")

password = input()
check_password(password)
# Out:
# a1@defgh
# Good

# %%
#IPS
#using regex

import re
def check_password(password):
  if re.match(r"^(?=.*[a-zA-Z])(?=.*\d)(?=.*[@$!%*?&])[A-Za-z\d@$!%*?&]{8,}$", password):
    print("Good")
  else:
    print("Bad")

password = input()

check_password(password)
# Out:
# a1234567
# Bad
